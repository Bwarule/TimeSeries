# %%
import pandas as pd
from datetime import datetime
from nsepy import get_history

# %%
def stock_perfo(stock_data):
    ## current price
    current_value = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-1],'Close']
    current_value
    ## Last 5days price
    Last5days = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-5],'Close']
    Last5days
    ## last 5days return 
    print(current_value[0],Last5days[0])
    R5 = (current_value[0]-Last5days[0])/current_value[0]
    R5

    Last2w = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-10],'Close']
    print('Current price', current_value[0],'; Last 2 week',Last2w[0])
    R_Last2w = (current_value[0]-Last2w[0])/current_value[0]
    R_Last2w

    Last3w = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-15],'Close']
    print('Current price', current_value[0],'; Last 3 week',Last3w[0])
    R_Last3w = (Last2w[0]-Last3w[0])/Last2w[0]
    R_Last3w
    
    Last4w = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-20],'Close']
    print('Current price', current_value[0],'; Last 4 week',Last4w[0])
    R_Last4w = (Last3w[0]-Last4w[0])/Last3w[0]
    R_Last4w
    
    Last2m = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-40],'Close']
    print('Current price', current_value[0],'; Last 2 Months',Last2m[0])
    R_Last2m = (Last4w[0]-Last2m[0])/Last4w[0]
    R_Last2m
    
    Last3m = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-65],'Close']
    print('Current price', current_value[0],'; Last 3 Months',Last3m[0])
    R_Last3m = (Last2m[0]-Last3m[0])/Last2m[0]
    R_Last3m
    
      
    # Last 1w,2w,3w,4w,2m,3m
    dict = {'Symbol':[stock_data['Symbol'][0]], '1w': [R5], '2w' : [R_Last2w], '3w' : [R_Last3w],
            '4w' : [R_Last4w], '2m':[R_Last2m] ,'3m':[R_Last3m]}
    
    dict1 = {'Symbol':[stock_data['Symbol'][0]],
            'current_value':[current_value[0]],
            '1w': [Last5days[0]],
            '2w' : [Last2w[0]], 
            '3w' : [Last3w[0]],
            '4w' : [Last4w[0]],
             '2m':[Last2m[0]] ,'3m':[Last3m[0]]}
    # creating a dataframe from dictionar
    df_output = pd.DataFrame(dict)
    
    return  df_output

# %%
def stock_perfo_byw(stock_data):
    ## current price
    current_value = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-1],'Close'][0]
    
    D1 = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-1],'Close'][0]
    D2 = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-2],'Close'][0]
    D3 = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-3],'Close'][0]
    D4 = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-4],'Close'][0]
    D5 = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-5],'Close'][0]
    D6 = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-6],'Close'][0]
    D7 = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-7],'Close'][0]
    D8 = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-8],'Close'][0]
    D9 = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-9],'Close'][0]
    D10 = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-10],'Close'][0]
    D11 = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-11],'Close'][0]
    D12 = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-12],'Close'][0]
    
    ## Last 5days price
    w1 = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-6],'Close'][0]
    
    w2 = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-11],'Close'][0]
    
    w3 = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-16],'Close'][0]
    
    w4 = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-21],'Close'][0]
    
    w5 = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-26],'Close'][0]
    
    w6 = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-31],'Close'][0]
    
    w7 = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-36],'Close'][0]
    
    w8 = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-41],'Close'][0]
    
    w9 = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-46],'Close'][0]
    
    w10 = stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-51],'Close'][0]
    
    ## last 5days return 
          
    # Last 1w,2w,3w,4w,2m,3m
    dict = {'Symbol':[stock_data['Symbol'][0]], 
            #'1D' :[(current_value-D1)/D1],
            '2D' :[(D1-D2)/D2],  '3D' : [(D2-D3)/D3], '4D' :[(D3-D4)/D4],  '5D': [(D4-D5)/D5],
            '6D' :[(D5-D6)/D6],  '7D' : [(D6-D7)/D7], '8D' :[(D7-D8)/D8],  '9D': [(D8-D9)/D9],
            '10D': [(D9-D10)/D10], '11D': [(D10-D11)/D11],'12D': [(D11-D12)/D12],
            'Week_wise' : [''],
            '1w': [(current_value-w1)/w1], '2w' : [(w1-w2)/w2], 
            '3w' : [(w2-w3)/w3], '4w' : [(w3-w4)/w4], '5w': [(w4-w5)/w5], '6w' : [(w5-w6)/w6],
            '7w' : [(w6-w7)/w7], '8w' : [(w7-w8)/w8], '9w': [(w8-w9)/w9], '10w': [(w9-w10)/w10]
            }
    
    # creating a dataframe from dictionar
    df_output = pd.DataFrame(dict)
    
    return  df_output

# %%
list_stock50 = ['GAIL', 'HEROMOTOCO', 'ITC', 'ICICIBANK', 'GRASIM', 'VEDL', 'UPL', 'POWERGRID', 'NTPC', 'WIPRO', 
              'JSWSTEEL', 'BAJAJ-AUTO', 'INDUSINDBK', 'BAJFINANCE','HINDUNILVR','SBIN', 'TATAMOTORS', 'ULTRACEMCO','TECHM',
              'TCS','AXISBANK', 'KOTAKBANK', 'ZEEL', 'SUNPHARMA', 'ONGC','LT', 'MARUTI', 'CIPLA', 'HDFC','BHARTIARTL',
              'NESTLEIND', 'COALINDIA','TATASTEEL','RELIANCE', 'BRITANNIA', 'TITAN', 'DRREDDY','HDFCBANK', 'HCLTECH',
              'HINDALCO', 'IOC', 'SHREECEM', 'ADANIPORTS', 'BAJAJFINSV', 'BPCL', 'M&M', 'ASIANPAINT',
              'INFY', 'EICHERMOT', 'INFRATEL']

# %%
s1 = datetime(2018,9,15)
s2 = datetime(2020,9,30)

# %%
stock_data = get_history(symbol='MUTHOOTFIN',start=s1, end=s2)

# %%
stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-1],'Close']
# Out:
# Date
# 2020-06-26    1090.0
# Name: Close, dtype: float64

# %%
liststock = ['BSE', 'COCHINSHIP', 'HUDCO', 'SBICARD','NATIONALUM','BPCL','NTPC',
             'ASHOKLEY','HAL','ICICIBANK', 'HINDZINC', 'YESBANK','ITDCEM', 'BERGEPAINT', 
             'BANKBARODA', 'DMART', 'BHEL','JISLJALEQS', 'NHPC','KRBL','HINDCOPPER','SHOPERSTOP',
             'KANSAINER', 'CDSL','BAJFINANCE', 'DHFL','MANAPPURAM','DABUR','AMBUJACEM',
             'TATAPOWER','JKTYRE','ASALCBR','DWARKESH', 'FINCABLES','WALCHANNAG','CHENNPETRO',             
              'STRTECH','KOKUYOCMLN', 'PRAJIND', 'ITC','IMAGICAA', 'ONGC',
              'BALAJITELE', 'DAAWAT', 'FORTIS', 'NECLIFE']

# %%
df_marks = stock_perfo_byw(stock_data) # pd.DataFrame()
for i, stock in enumerate(liststock):
    print('stock name :',stock)
    stock_data = get_history(symbol=stock,start=s1, end=s2)
    new_row = stock_perfo_byw(stock_data)
    df_marks = df_marks.append(new_row, ignore_index=True)
# Out:
# stock name : BSE
# stock name : COCHINSHIP
# stock name : HUDCO
# stock name : SBICARD
# stock name : NATIONALUM
# stock name : BPCL
# stock name : NTPC
# stock name : ASHOKLEY
# stock name : HAL
# stock name : ICICIBANK
# stock name : HINDZINC
# stock name : YESBANK
# stock name : ITDCEM
# stock name : BERGEPAINT
# stock name : BANKBARODA
# stock name : DMART
# stock name : BHEL
# stock name : JISLJALEQS
# stock name : NHPC
# stock name : KRBL
# stock name : HINDCOPPER
# stock name : SHOPERSTOP
# stock name : KANSAINER
# stock name : CDSL
# stock name : BAJFINANCE
# stock name : DHFL
# stock name : MANAPPURAM
# stock name : DABUR
# stock name : AMBUJACEM
# stock name : TATAPOWER
# stock name : JKTYRE
# stock name : ASALCBR
# stock name : DWARKESH
# stock name : FINCABLES
# stock name : WALCHANNAG
# stock name : CHENNPETRO
# stock name : STRTECH
# stock name : KOKUYOCMLN
# stock name : PRAJIND
# stock name : ITC
# stock name : IMAGICAA
# stock name : ONGC
# stock name : BALAJITELE
# stock name : DAAWAT
# stock name : FORTIS
# stock name : NECLIFE

# %%
df_marks
# Out:
#         Symbol        2D        3D        4D        5D        6D        7D  \
# 0   MUTHOOTFIN -0.013396 -0.007144 -0.013782 -0.025311 -0.018983  0.003572
# 1          BSE -0.014461  0.014450 -0.015421  0.094236  0.019012  0.017873
# 2   COCHINSHIP  0.053395 -0.020026  0.013587  0.014616  0.030640 -0.020784
# 3        HUDCO  0.005405  0.009091 -0.016100  0.035185  0.040462  0.005814
# 4      SBICARD -0.002981 -0.015577 -0.022796  0.033516  0.066375  0.049413
# 5   NATIONALUM -0.017595  0.057364 -0.041605  0.040185  0.055465  0.008224
# 6         BPCL  0.063201 -0.021926 -0.034311  0.017785  0.012088  0.027819
# 7         NTPC  0.009365 -0.009789 -0.036725  0.057188  0.024731  0.003236
# 8     ASHOKLEY -0.018709 -0.012927 -0.037333  0.030220  0.004600  0.062561
# 9          HAL -0.038377  0.133830 -0.018888 -0.001052  0.006779 -0.007012
# 10   ICICIBANK -0.005413  0.008331 -0.074571  0.023398  0.010308  0.033523
# 11    HINDZINC  0.049038  0.014442 -0.005321  0.000532  0.055041 -0.002242
# 12     YESBANK -0.009259 -0.001848 -0.018149 -0.007207 -0.008929  0.000000
# 13      ITDCEM  0.043152  0.023033 -0.032498  0.096741 -0.009082 -0.024606
# 14  BERGEPAINT -0.018070 -0.038092  0.049079  0.019984  0.009790  0.002303
# 15  BANKBARODA -0.002885  0.007752  0.021782  0.022267  0.049947  0.023939
# 16       DMART -0.004836 -0.022389 -0.000657  0.004042 -0.005395  0.005232
# 17        BHEL -0.025099  0.041265  0.041547  0.037147  0.036980  0.022047
# 18  JISLJALEQS  0.049020  0.040816  0.042553  0.044444  0.046512  0.048780
# 19        NHPC  0.027094 -0.012165  0.002439  0.022444  0.007538  0.002519
# 20        KRBL  0.036787  0.019163 -0.019404 -0.013897  0.002220  0.007115
# 21  HINDCOPPER -0.001506  0.034268 -0.025797  0.036164  0.022508 -0.023548
# 22  SHOPERSTOP  0.012889 -0.003351 -0.023186  0.011589  0.007506  0.005310
# 23   KANSAINER  0.007230  0.054042  0.075509  0.009908  0.029438 -0.004115
# 24        CDSL -0.020506  0.021680 -0.038704  0.068488  0.002063 -0.001311
# 25  BAJFINANCE -0.033890  0.024161 -0.030094  0.065204  0.052509  0.068351
# 26        DHFL  0.006270 -0.003125 -0.047619  0.033846  0.038339  0.046823
# 27  MANAPPURAM -0.006351  0.043061 -0.030819 -0.015798  0.043865  0.016767
# 28       DABUR  0.002614  0.009010 -0.007741  0.034047  0.001016  0.006932
# 29   AMBUJACEM  0.009396 -0.012984 -0.023545  0.011251  0.001572  0.018415
# 9   0.040602  0.072977 -0.026293 -0.027564 -0.027184 -0.026640
# 10  0.090506 -0.070250 -0.027765 -0.090970  0.102694  0.026272
# 11  0.013290 -0.093683  0.059257  0.029180  0.027894 -0.021714
# 12 -0.001859 -0.046099  0.003559  0.001783 -0.052365  0.208163
# 13  0.029326 -0.040788  0.053333 -0.089069 -0.076060  0.095628
# 14  0.056504  0.023079  0.009542 -0.128758 -0.025252  0.035112
# 15  0.037284 -0.129780  0.015294 -0.116424 -0.004141 -0.013279
# 16 -0.023494 -0.056321 -0.032034  0.108876  0.075166  0.095120
# 17  0.095890 -0.069217  0.190889  0.100239 -0.018735 -0.004662
# 18 -0.197802 -0.031915 -0.203390 -0.070866 -0.092857  0.007194
# 19 -0.017544 -0.002500 -0.017199 -0.035545 -0.002364 -0.047297
# 20  0.043442 -0.037265  0.031241 -0.039565 -0.092093  0.047475
# 21  0.021654 -0.013592  0.064050 -0.050980  0.000000 -0.007782
# 22  0.026355 -0.167398 -0.032160 -0.135589  0.000000 -0.035416
# 23  0.010561 -0.002772 -0.031929 -0.068599  0.053997  0.084250
# 24  0.031517  0.077356  0.029398 -0.066551  0.056380  0.005739
# 25 -0.018365 -0.057670  0.024969 -0.102724  0.068986 -0.015670
# 26 -0.012605 -0.055556  0.095652 -0.098039 -0.111498  0.264317
# 27  0.050336 -0.031288  0.003261 -0.026587  0.232877  0.001470
# 28  0.059752 -0.040231  0.037791 -0.076006 -0.048637 -0.000298
# 29  0.058287 -0.008219  0.082444 -0.005310 -0.039660  0.047167
# 30  0.112633  0.063107  0.065517 -0.067524 -0.040123 -0.075606
# 31  0.051205 -0.004995 -0.027211  0.010806 -0.037807  0.165198
# 32  0.123783  0.004634  0.018888  0.127144 -0.011978  0.055830
# 33 -0.005587  0.022857 -0.005682 -0.043478 -0.005405 -0.048843
# 34  0.095030 -0.082467 -0.079600 -0.066964  0.045619 -0.019759
# 35 -0.190476  0.417178  0.275930  0.042857 -0.236760 -0.171613
# 36  0.069336 -0.105677 -0.019692 -0.054251 -0.032890  0.012688
# 37 -0.053492  0.008492  0.074611  0.021942 -0.005998  0.149123
# 38  0.207650 -0.011879 -0.167266  0.093412 -0.042373  0.085890
# 39  0.048736 -0.024648 -0.034834 -0.059904 -0.052233  0.068770
# 40  0.044456  0.153541  0.017391 -0.116113 -0.000549 -0.037497
# 41 -0.130952  0.354839  0.265306 -0.020000 -0.074074 -0.114754
# 42  0.080519  0.011162  0.007275  0.072340  0.078806 -0.121049
# 43 -0.042484 -0.042254  0.155515 -0.018634  0.090997  0.322663
# 44  0.265060 -0.014252  0.016908 -0.065463 -0.004494 -0.002242
# 45 -0.007296 -0.010195 -0.050806  0.058472 -0.049493  0.018595
# 46  0.000000 -0.076923  0.059259 -0.096990  0.060284 -0.090323
#
# [47 rows x 23 columns]

# %%
from datetime import date

today = date.today()
print("Today's date:", today)
# Out:
# Today's date: 2020-06-29

# %%
#filename = 'Nifty_50_perfo_'+ str(today) +'.xlsx'

# %%
filename = 'bharat_perfo_'+ str(today) +'.xlsx'

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter(filename, engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df_marks.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
stock_data.loc[stock_data.index == stock_data.index[stock_data.shape[0]-1],'Close']
# Out:
# Date
# 2020-06-25    228.45
# Name: Close, dtype: float64

# %%
stock_data.tail(2)
# Out:
#               Symbol Series  Prev Close   Open   High    Low    Last   Close  \
# Date
# 2020-06-24  INFRATEL     EQ      232.35  233.0  237.5  227.4  231.25  233.05
# 2020-06-25  INFRATEL     EQ      233.05  222.0  232.4  218.0  229.50  228.45
#
#               VWAP    Volume      Turnover  Trades Deliverable Volume  \
# Date
# 2020-06-24  232.42  10264786  2.385721e+14   83303            2590667
# 2020-06-25  225.81  15312037  3.457615e+14  142843            2648012
#
#             %Deliverble
# Date
# 2020-06-24       0.2524
# 2020-06-25       0.1729

# %%
stock_data = get_history(symbol='BSE',start=s1, end=s2)

# %%
stock_data
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2018-09-17    BSE     EQ      730.70  731.00  782.90  731.00  781.00  778.70
# 2018-09-18    BSE     EQ      778.70  778.70  784.00  755.40  756.00  757.85
# 2018-09-19    BSE     EQ      757.85  757.85  757.85  732.00  735.50  736.15
# 2018-09-21    BSE     EQ      736.15  756.00  758.80  710.15  710.35  717.40
# 2018-09-24    BSE     EQ      717.40  725.30  728.00  712.00  721.00  721.90
# ...           ...    ...         ...     ...     ...     ...     ...     ...
# 2020-06-19    BSE     EQ      405.65  409.00  422.50  407.00  414.00  412.90
# 2020-06-22    BSE     EQ      412.90  417.00  424.00  414.00  424.00  420.75
# 2020-06-23    BSE     EQ      420.75  504.80  504.80  456.00  461.80  460.40
# 2020-06-24    BSE     EQ      460.40  463.90  468.60  450.05  453.45  453.30
# 2020-06-25    BSE     EQ      453.30  441.00  462.90  441.00  459.70  459.85
#
#               VWAP   Volume      Turnover Trades Deliverable Volume  \
# Date
# 2018-09-17  768.89   568560  4.371587e+13  30443             340203
# 2018-09-18  765.71   174974  1.339802e+13   8642             118742
# 2018-09-19  741.39   166391  1.233612e+13  11172             116555
# 2018-09-21  734.92   574166  4.219668e+13  24993             429545
# 2018-09-24  721.00   126374  9.111546e+12   5506              77888
# ...            ...      ...           ...    ...                ...
# 2020-06-19  415.59   286298  1.189830e+13   7265             144900
# 2020-06-22  418.66   157688  6.601708e+12   4563              79991
# 2020-06-23  468.23  1784676  8.356408e+13  44789             488618
# 2020-06-24  458.14   409153  1.874483e+13  10982             162755
# 2020-06-25  456.14   244551  1.115491e+13   7643             101442
#
#             %Deliverble
# Date
# 2018-09-17       0.5984
# 2018-09-18       0.6786
# 2018-09-19       0.7005
# 2018-09-21       0.7481
# 2018-09-24       0.6163
# ...                 ...
# 2020-06-19       0.5061
# 2020-06-22       0.5073
# 2020-06-23       0.3947
# 2020-06-24       0.3978
# 2020-06-25       0.4148
#
# [435 rows x 14 columns]

# %%
((459.8-453.30)/453.3)*100
# Out:
# 1.4339289653651004

# %%
stock_perfo_byw(stock_data)
# Out:
#   Symbol       2D        3D        4D        5D        6D        7D       8D  \
# 0    BSE  0.01445 -0.015421  0.094236  0.019012  0.017873  0.047515 -0.00883
#
#          9D       10D  ...        1w        2w        3w        4w        5w  \
# 0  0.007089 -0.005639  ...  0.133613  0.029438  0.008316 -0.012508 -0.114455
#
#          6w        7w        8w        9w       10w
# 0  0.084709  0.080939  0.029579  0.014108  0.104204
#
# [1 rows x 23 columns]

# %%
# [(D1-D2)/D2]
((459.85-453.3))/(453.3)
# Out:
# 0.014449591881756036
